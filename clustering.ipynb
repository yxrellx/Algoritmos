# %% [markdown]
# <a href="https://colab.research.google.com/github/yxrellx/Algoritmos/blob/main/clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/elinar.csv')
df
# Out:
#       patient_id  age_at_diagnosis type_of_breast_surgery    cancer_type  \
# 0              2                43      BREAST CONSERVING  Breast Cancer
# 1              8                76             MASTECTOMY  Breast Cancer
# 2             10                78             MASTECTOMY  Breast Cancer
# 3             28                86      BREAST CONSERVING  Breast Cancer
# 4             35                84             MASTECTOMY  Breast Cancer
# ...          ...               ...                    ...            ...
# 1511        7278                67             MASTECTOMY  Breast Cancer
# 1512        7280                63             MASTECTOMY  Breast Cancer
# 1513        7284                61             MASTECTOMY  Breast Cancer
# 1514        7286                66             MASTECTOMY  Breast Cancer
# 1515        7295                43      BREAST CONSERVING  Breast Cancer
#
#                            cancer_type_detailed cellularity  chemotherapy  \
# 0              Breast Invasive Ductal Carcinoma        High             0
# 1     Breast Mixed Ductal and Lobular Carcinoma        High             1
# 2              Breast Invasive Ductal Carcinoma    Moderate             0
# 3              Breast Invasive Ductal Carcinoma    Moderate             0
# 4              Breast Invasive Ductal Carcinoma        High             0
# ...                                         ...         ...           ...
# 1511           Breast Invasive Ductal Carcinoma        High             0
# 1512           Breast Invasive Ductal Carcinoma        High             0
# 1513           Breast Invasive Ductal Carcinoma        High             0
# 1514           Breast Invasive Ductal Carcinoma        High             0
# 1515           Breast Invasive Ductal Carcinoma        High             0
#
#      pam50_+_claudin-low_subtype  cohort er_status_measured_by_ihc  ...  \
# 0                           LumA       1                   Positve  ...
# 1                           LumB       1                   Positve  ...
# 2                           LumB       1                   Positve  ...
# 3                           LumB       1                   Positve  ...
# 4                           Her2       1                  Negative  ...
# ...                          ...     ...                       ...  ...
# 1511                        LumA       4                   Positve  ...
# 1512                        LumA       4                   Positve  ...
# 1513                        LumA       4                   Positve  ...
# 1514                        LumB       4                   Positve  ...
# 1515                        LumA       4                   Positve  ...
#
#      inferred_menopausal_state (2)  integrative_cluster (2)  \
# 0                                1                        0
# 1                                0                        2
# 2                                0                        3
# 3                                0                        2
# 4                                0                        1
# ...                            ...                      ...
# 1511                             0                        1
# 1512                             0                        3
# 1513                             0                       10
# 1514                             0                        1
# 1515                             1                        1
#
#      primary_tumor_laterality (2) oncotree_code (2) pr_status (2)  \
# 0                               0                 0             1
# 1                               0                 1             1
# 2                               1                 0             1
# 3                               0                 0             0
# 4                               1                 0             0
# ...                           ...               ...           ...
# 1511                            1                 0             1
# 1512                            1                 0             1
# 1513                            0                 0             0
# 1514                            1                 0             0
# 1515                            0                 2             1
#
#       3-gene_classifier_subtype (2) death_from_cancer (2) tumor_area  \
# 0                                 1                     0   0.000276
# 1                                 1                     1   0.002373
# 2                                 1                     1   0.003653
# 3                                 1                     2   0.000916
# 4                                 1                     1   0.001644
# ...                             ...                   ...        ...
# 1511                              5                     2   0.012834
# 1512                              4                     0   0.023726
# 1513                              5                     2   0.012834
# 1514                              4                     2   0.036559
# 1515                              5                     0   0.014624
#
#      quimio_terapia(2)  radio_terapia(2)
# 0                   SI                SI
# 1                   No                SI
# 2                   SI                SI
# 3                   SI                SI
# 4                   SI                No
# ...                ...               ...
# 1511                SI                No
# 1512                SI                No
# 1513                SI                No
# 1514                SI                No
# 1515                SI                SI
#
# [1516 rows x 51 columns]

# %%
df =df.drop(['patient_id','type_of_breast_surgery','cancer_type','cancer_type_detailed',"cellularity","pam50_+_claudin-low_subtype","er_status_measured_by_ihc","er_status", "her2_status_measured_by_snp6", "her2_status", "tumor_other_histologic_subtype", "inferred_menopausal_state","integrative_cluster", "primary_tumor_laterality","oncotree_code","pr_status","3-gene_classifier_subtype", "death_from_cancer","quimio_terapia(2)", "radio_terapia(2)"],axis=1)
df
# Out:
#       age_at_diagnosis  chemotherapy  cohort  neoplasm_histologic_grade  \
# 0                   43             0       1                          3
# 1                   76             1       1                          3
# 2                   78             0       1                          3
# 3                   86             0       1                          3
# 4                   84             0       1                          2
# ...                ...           ...     ...                        ...
# 1511                67             0       4                          2
# 1512                63             0       4                          2
# 1513                61             0       4                          3
# 1514                66             0       4                          3
# 1515                43             0       4                          3
#
#       hormone_therapy  lymph_nodes_examined_positive  mutation_count  \
# 0                   1                              0               2
# 1                   1                              8               2
# 2                   1                              0               4
# 3                   1                              1               5
# 4                   0                              0               1
# ...               ...                            ...             ...
# 1511                1                              1               3
# 1512                1                              6               6
# 1513                1                              1               5
# 1514                1                              3               2
# 1515                1                              1               4
#
#       nottingham_prognostic_index  overall_survival_months  overall_survival  \
# 0                        0.000065             8.466155e-01                 1
# 1                        0.000099             4.138046e-01                 0
# 2                        0.006730             7.802601e-09                 0
# 3                        0.008339             3.657886e-01                 0
# 4                        0.005066             3.627876e-01                 0
# ...                           ...                      ...               ...
# 1511                     0.000065             2.410804e-08                 0
# 1512                     0.000083             1.955985e-01                 1
# 1513                     0.000082             2.030677e-08                 0
# 1514                     0.000082             1.586862e-01                 0
# 1515                     0.000082             1.969323e-01                 1
#
#       ...  her2_status (2)  tumor_other_histologic_subtype (2)  \
# 0     ...                0                                   0
# 1     ...                0                                   1
# 2     ...                0                                   0
# 3     ...                0                                   0
# 4     ...                0                                   2
# ...   ...              ...                                 ...
# 1511  ...                0                                   0
# 1512  ...                0                                   0
# 1513  ...                0                                   0
# 1514  ...                0                                   0
# 1515  ...                0                                   2
#
#       inferred_menopausal_state (2)  integrative_cluster (2)  \
# 0                                 1                        0
# 1                                 0                        2
# 2                                 0                        3
# 3                                 0                        2
# 4                                 0                        1
# ...                             ...                      ...
# 1511                              0                        1
# 1512                              0                        3
# 1513                              0                       10
# 1514                              0                        1
# 1515                              1                        1
#
#       primary_tumor_laterality (2)  oncotree_code (2)  pr_status (2)  \
# 0                                0                  0              1
# 1                                0                  1              1
# 2                                1                  0              1
# 3                                0                  0              0
# 4                                1                  0              0
# ...                            ...                ...            ...
# 1511                             1                  0              1
# 1512                             1                  0              1
# 1513                             0                  0              0
# 1514                             1                  0              0
# 1515                             0                  2              1
#
#       3-gene_classifier_subtype (2)  death_from_cancer (2)  tumor_area
# 0                                 1                      0    0.000276
# 1                                 1                      1    0.002373
# 2                                 1                      1    0.003653
# 3                                 1                      2    0.000916
# 4                                 1                      1    0.001644
# ...                             ...                    ...         ...
# 1511                              5                      2    0.012834
# 1512                              4                      0    0.023726
# 1513                              5                      2    0.012834
# 1514                              4                      2    0.036559
# 1515                              5                      0    0.014624
#
# [1516 rows x 31 columns]

# %%
features = df.values

# %%
from sklearn.cluster import KMeans
common_params = {
    "n_init": "auto",
    "random_state": 2,
}
modelo = KMeans(n_clusters=10, **common_params)
y_pred = modelo.fit_predict(features)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, random_state=0)
reduced_features = pca.fit_transform(features)
reduced_cluster_centers = pca.transform(modelo.cluster_centers_)
y_pred = modelo.predict(features)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=y_pred)
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')
ax.grid(True)
ax.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
len(y_pred)
# Out:
# 1516

# %%
df.reset_index(inplace=True, drop=False)

# %%
ndf = df.copy()
ndf = pd.concat([ndf, pd.DataFrame(y_pred)], axis=1)
ndf
# Out:
#       index  age_at_diagnosis  chemotherapy  cohort  \
# 0         0                43             0       1
# 1         1                76             1       1
# 2         2                78             0       1
# 3         3                86             0       1
# 4         4                84             0       1
# ...     ...               ...           ...     ...
# 1511   1511                67             0       4
# 1512   1512                63             0       4
# 1513   1513                61             0       4
# 1514   1514                66             0       4
# 1515   1515                43             0       4
#
#       neoplasm_histologic_grade  hormone_therapy  \
# 0                             3                1
# 1                             3                1
# 2                             3                1
# 3                             3                1
# 4                             2                0
# ...                         ...              ...
# 1511                          2                1
# 1512                          2                1
# 1513                          3                1
# 1514                          3                1
# 1515                          3                1
#
#       lymph_nodes_examined_positive  mutation_count  \
# 0                                 0               2
# 1                                 8               2
# 2                                 0               4
# 3                                 1               5
# 4                                 0               1
# ...                             ...             ...
# 1511                              1               3
# 1512                              6               6
# 1513                              1               5
# 1514                              3               2
# 1515                              1               4
#
#       nottingham_prognostic_index  overall_survival_months  ...  \
# 0                        0.000065             8.466155e-01  ...
# 1                        0.000099             4.138046e-01  ...
# 2                        0.006730             7.802601e-09  ...
# 3                        0.008339             3.657886e-01  ...
# 4                        0.005066             3.627876e-01  ...
# ...                           ...                      ...  ...
# 1511                     0.000065             2.410804e-08  ...
# 1512                     0.000083             1.955985e-01  ...
# 1513                     0.000082             2.030677e-08  ...
# 1514                     0.000082             1.586862e-01  ...
# 1515                     0.000082             1.969323e-01  ...
#
#       tumor_other_histologic_subtype (2)  inferred_menopausal_state (2)  \
# 0                                      0                              1
# 1                                      1                              0
# 2                                      0                              0
# 3                                      0                              0
# 4                                      2                              0
# ...                                  ...                            ...
# 1511                                   0                              0
# 1512                                   0                              0
# 1513                                   0                              0
# 1514                                   0                              0
# 1515                                   2                              1
#
#       integrative_cluster (2)  primary_tumor_laterality (2)  \
# 0                           0                             0
# 1                           2                             0
# 2                           3                             1
# 3                           2                             0
# 4                           1                             1
# ...                       ...                           ...
# 1511                        1                             1
# 1512                        3                             1
# 1513                       10                             0
# 1514                        1                             1
# 1515                        1                             0
#
#       oncotree_code (2)  pr_status (2)  3-gene_classifier_subtype (2)  \
# 0                     0              1                              1
# 1                     1              1                              1
# 2                     0              1                              1
# 3                     0              0                              1
# 4                     0              0                              1
# ...                 ...            ...                            ...
# 1511                  0              1                              5
# 1512                  0              1                              4
# 1513                  0              0                              5
# 1514                  0              0                              4
# 1515                  2              1                              5
#
#       death_from_cancer (2)  tumor_area  0
# 0                         0    0.000276  7
# 1                         1    0.002373  6
# 2                         1    0.003653  2
# 3                         2    0.000916  2
# 4                         1    0.001644  2
# ...                     ...         ... ..
# 1511                      2    0.012834  4
# 1512                      0    0.023726  3
# 1513                      2    0.012834  3
# 1514                      2    0.036559  4
# 1515                      0    0.014624  7
#
# [1516 rows x 33 columns]

# %%
ndf.rename(columns={0:"Cluster"},inplace=True)
ndf
# Out:
#       index  age_at_diagnosis  chemotherapy  cohort  \
# 0         0                43             0       1
# 1         1                76             1       1
# 2         2                78             0       1
# 3         3                86             0       1
# 4         4                84             0       1
# ...     ...               ...           ...     ...
# 1511   1511                67             0       4
# 1512   1512                63             0       4
# 1513   1513                61             0       4
# 1514   1514                66             0       4
# 1515   1515                43             0       4
#
#       neoplasm_histologic_grade  hormone_therapy  \
# 0                             3                1
# 1                             3                1
# 2                             3                1
# 3                             3                1
# 4                             2                0
# ...                         ...              ...
# 1511                          2                1
# 1512                          2                1
# 1513                          3                1
# 1514                          3                1
# 1515                          3                1
#
#       lymph_nodes_examined_positive  mutation_count  \
# 0                                 0               2
# 1                                 8               2
# 2                                 0               4
# 3                                 1               5
# 4                                 0               1
# ...                             ...             ...
# 1511                              1               3
# 1512                              6               6
# 1513                              1               5
# 1514                              3               2
# 1515                              1               4
#
#       nottingham_prognostic_index  overall_survival_months  ...  \
# 0                        0.000065             8.466155e-01  ...
# 1                        0.000099             4.138046e-01  ...
# 2                        0.006730             7.802601e-09  ...
# 3                        0.008339             3.657886e-01  ...
# 4                        0.005066             3.627876e-01  ...
# ...                           ...                      ...  ...
# 1511                     0.000065             2.410804e-08  ...
# 1512                     0.000083             1.955985e-01  ...
# 1513                     0.000082             2.030677e-08  ...
# 1514                     0.000082             1.586862e-01  ...
# 1515                     0.000082             1.969323e-01  ...
#
#       tumor_other_histologic_subtype (2)  inferred_menopausal_state (2)  \
# 0                                      0                              1
# 1                                      1                              0
# 2                                      0                              0
# 3                                      0                              0
# 4                                      2                              0
# ...                                  ...                            ...
# 1511                                   0                              0
# 1512                                   0                              0
# 1513                                   0                              0
# 1514                                   0                              0
# 1515                                   2                              1
#
#       integrative_cluster (2)  primary_tumor_laterality (2)  \
# 0                           0                             0
# 1                           2                             0
# 2                           3                             1
# 3                           2                             0
# 4                           1                             1
# ...                       ...                           ...
# 1511                        1                             1
# 1512                        3                             1
# 1513                       10                             0
# 1514                        1                             1
# 1515                        1                             0
#
#       oncotree_code (2)  pr_status (2)  3-gene_classifier_subtype (2)  \
# 0                     0              1                              1
# 1                     1              1                              1
# 2                     0              1                              1
# 3                     0              0                              1
# 4                     0              0                              1
# ...                 ...            ...                            ...
# 1511                  0              1                              5
# 1512                  0              1                              4
# 1513                  0              0                              5
# 1514                  0              0                              4
# 1515                  2              1                              5
#
#       death_from_cancer (2)  tumor_area  Cluster
# 0                         0    0.000276        7
# 1                         1    0.002373        6
# 2                         1    0.003653        2
# 3                         2    0.000916        2
# 4                         1    0.001644        2
# ...                     ...         ...      ...
# 1511                      2    0.012834        4
# 1512                      0    0.023726        3
# 1513                      2    0.012834        3
# 1514                      2    0.036559        4
# 1515                      0    0.014624        7
#
# [1516 rows x 33 columns]

# %%
ndf[ndf["Cluster"]==0]
# Out:
#       index  age_at_diagnosis  chemotherapy  cohort  \
# 47       47                70             0       1
# 87       87                75             0       1
# 130     130                82             0       1
# 162     162                73             0       1
# 275     275                71             0       1
# ...     ...               ...           ...     ...
# 1422   1422                72             1       4
# 1429   1429                67             0       4
# 1452   1452                67             0       4
# 1472   1472                74             0       4
# 1473   1473                77             0       4
#
#       neoplasm_histologic_grade  hormone_therapy  \
# 47                            2                1
# 87                            2                1
# 130                           3                1
# 162                           2                0
# 275                           3                1
# ...                         ...              ...
# 1422                          2                1
# 1429                          3                1
# 1452                          3                1
# 1472                          2                1
# 1473                          3                1
#
#       lymph_nodes_examined_positive  mutation_count  \
# 47                                0              11
# 87                                0              11
# 130                               2              21
# 162                               7              22
# 275                               1               8
# ...                             ...             ...
# 1422                              2               8
# 1429                              0              14
# 1452                              3              11
# 1472                              0              12
# 1473                              0              14
#
#       nottingham_prognostic_index  overall_survival_months  ...  \
# 47                       0.000049             1.110370e-08  ...
# 87                       0.000049             1.220407e-08  ...
# 130                      0.000082             4.298099e-01  ...
# 162                      0.008511             8.992998e-09  ...
# 275                      0.000083             1.284428e-08  ...
# ...                           ...                      ...  ...
# 1422                     0.006704             4.384795e-01  ...
# 1429                     0.006702             1.140380e-08  ...
# 1452                     0.000082             5.695232e-01  ...
# 1472                     0.000049             1.420473e-08  ...
# 1473                     0.067404             1.085028e-01  ...
#
#       tumor_other_histologic_subtype (2)  inferred_menopausal_state (2)  \
# 47                                     0                              0
# 87                                     1                              0
# 130                                    0                              0
# 162                                    1                              0
# 275                                    0                              0
# ...                                  ...                            ...
# 1422                                   0                              0
# 1429                                   0                              0
# 1452                                   0                              0
# 1472                                   0                              0
# 1473                                   0                              0
#
#       integrative_cluster (2)  primary_tumor_laterality (2)  \
# 47                          0                             1
# 87                          1                             0
# 130                         1                             1
# 162                         9                             0
# 275                         2                             0
# ...                       ...                           ...
# 1422                        4                             1
# 1429                        5                             1
# 1452                        6                             1
# 1472                        6                             0
# 1473                        7                             0
#
#       oncotree_code (2)  pr_status (2)  3-gene_classifier_subtype (2)  \
# 47                    0              0                              0
# 87                    1              1                              4
# 130                   0              1                              4
# 162                   1              0                              4
# 275                   0              1                              4
# ...                 ...            ...                            ...
# 1422                  0              0                              5
# 1429                  0              0                              6
# 1452                  0              0                              4
# 1472                  0              0                              4
# 1473                  0              0                              0
#
#       death_from_cancer (2)  tumor_area  Cluster
# 47                        0    0.001159        0
# 87                        0    0.002373        0
# 130                       1    0.002069        0
# 162                       1    0.008022        0
# 275                       0    0.005379        0
# ...                     ...         ...      ...
# 1422                      1    0.012803        0
# 1429                      0    0.012500        0
# 1452                      1    0.008829        0
# 1472                      0    0.021204        0
# 1473                      2    0.032700        0
#
# [97 rows x 33 columns]

# %% [markdown]
# MEJORIA-Algoritmo

# %%
from sklearn.cluster import KMeans
common_params = {
    "n_init": "auto",
    "random_state": 8,
}
modelo = KMeans(n_clusters=10, **common_params)
y_pred = modelo.fit_predict(features)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, random_state=0)
reduced_features = pca.fit_transform(features)
reduced_cluster_centers = pca.transform(modelo.cluster_centers_)
y_pred = modelo.predict(features)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.scatter(reduced_features[:,0], reduced_features[:,1], c=y_pred)
plt.scatter(reduced_cluster_centers[:, 0], reduced_cluster_centers[:,1], marker='x', s=150, c='b')
ax.grid(True)
ax.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
len(y_pred)
# Out:
# 1516

# %%
df.reset_index(inplace=True, drop=False)

# %%
ndf = df.copy()
ndf = pd.concat([ndf, pd.DataFrame(y_pred)], axis=1)
ndf
# Out:
#       level_0  index  age_at_diagnosis  chemotherapy  cohort  \
# 0           0      0                43             0       1
# 1           1      1                76             1       1
# 2           2      2                78             0       1
# 3           3      3                86             0       1
# 4           4      4                84             0       1
# ...       ...    ...               ...           ...     ...
# 1511     1511   1511                67             0       4
# 1512     1512   1512                63             0       4
# 1513     1513   1513                61             0       4
# 1514     1514   1514                66             0       4
# 1515     1515   1515                43             0       4
#
#       neoplasm_histologic_grade  hormone_therapy  \
# 0                             3                1
# 1                             3                1
# 2                             3                1
# 3                             3                1
# 4                             2                0
# ...                         ...              ...
# 1511                          2                1
# 1512                          2                1
# 1513                          3                1
# 1514                          3                1
# 1515                          3                1
#
#       lymph_nodes_examined_positive  mutation_count  \
# 0                                 0               2
# 1                                 8               2
# 2                                 0               4
# 3                                 1               5
# 4                                 0               1
# ...                             ...             ...
# 1511                              1               3
# 1512                              6               6
# 1513                              1               5
# 1514                              3               2
# 1515                              1               4
#
#       nottingham_prognostic_index  ...  tumor_other_histologic_subtype (2)  \
# 0                        0.000065  ...                                   0
# 1                        0.000099  ...                                   1
# 2                        0.006730  ...                                   0
# 3                        0.008339  ...                                   0
# 4                        0.005066  ...                                   2
# ...                           ...  ...                                 ...
# 1511                     0.000065  ...                                   0
# 1512                     0.000083  ...                                   0
# 1513                     0.000082  ...                                   0
# 1514                     0.000082  ...                                   0
# 1515                     0.000082  ...                                   2
#
#       inferred_menopausal_state (2)  integrative_cluster (2)  \
# 0                                 1                        0
# 1                                 0                        2
# 2                                 0                        3
# 3                                 0                        2
# 4                                 0                        1
# ...                             ...                      ...
# 1511                              0                        1
# 1512                              0                        3
# 1513                              0                       10
# 1514                              0                        1
# 1515                              1                        1
#
#       primary_tumor_laterality (2)  oncotree_code (2)  pr_status (2)  \
# 0                                0                  0              1
# 1                                0                  1              1
# 2                                1                  0              1
# 3                                0                  0              0
# 4                                1                  0              0
# ...                            ...                ...            ...
# 1511                             1                  0              1
# 1512                             1                  0              1
# 1513                             0                  0              0
# 1514                             1                  0              0
# 1515                             0                  2              1
#
#       3-gene_classifier_subtype (2)  death_from_cancer (2)  tumor_area  0
# 0                                 1                      0    0.000276  1
# 1                                 1                      1    0.002373  5
# 2                                 1                      1    0.003653  5
# 3                                 1                      2    0.000916  5
# 4                                 1                      1    0.001644  5
# ...                             ...                    ...         ... ..
# 1511                              5                      2    0.012834  6
# 1512                              4                      0    0.023726  6
# 1513                              5                      2    0.012834  0
# 1514                              4                      2    0.036559  6
# 1515                              5                      0    0.014624  1
#
# [1516 rows x 34 columns]

# %%
ndf.rename(columns={0:"Cluster"},inplace=True)
ndf
# Out:
#       level_0  index  age_at_diagnosis  chemotherapy  cohort  \
# 0           0      0                43             0       1
# 1           1      1                76             1       1
# 2           2      2                78             0       1
# 3           3      3                86             0       1
# 4           4      4                84             0       1
# ...       ...    ...               ...           ...     ...
# 1511     1511   1511                67             0       4
# 1512     1512   1512                63             0       4
# 1513     1513   1513                61             0       4
# 1514     1514   1514                66             0       4
# 1515     1515   1515                43             0       4
#
#       neoplasm_histologic_grade  hormone_therapy  \
# 0                             3                1
# 1                             3                1
# 2                             3                1
# 3                             3                1
# 4                             2                0
# ...                         ...              ...
# 1511                          2                1
# 1512                          2                1
# 1513                          3                1
# 1514                          3                1
# 1515                          3                1
#
#       lymph_nodes_examined_positive  mutation_count  \
# 0                                 0               2
# 1                                 8               2
# 2                                 0               4
# 3                                 1               5
# 4                                 0               1
# ...                             ...             ...
# 1511                              1               3
# 1512                              6               6
# 1513                              1               5
# 1514                              3               2
# 1515                              1               4
#
#       nottingham_prognostic_index  ...  tumor_other_histologic_subtype (2)  \
# 0                        0.000065  ...                                   0
# 1                        0.000099  ...                                   1
# 2                        0.006730  ...                                   0
# 3                        0.008339  ...                                   0
# 4                        0.005066  ...                                   2
# ...                           ...  ...                                 ...
# 1511                     0.000065  ...                                   0
# 1512                     0.000083  ...                                   0
# 1513                     0.000082  ...                                   0
# 1514                     0.000082  ...                                   0
# 1515                     0.000082  ...                                   2
#
#       inferred_menopausal_state (2)  integrative_cluster (2)  \
# 0                                 1                        0
# 1                                 0                        2
# 2                                 0                        3
# 3                                 0                        2
# 4                                 0                        1
# ...                             ...                      ...
# 1511                              0                        1
# 1512                              0                        3
# 1513                              0                       10
# 1514                              0                        1
# 1515                              1                        1
#
#       primary_tumor_laterality (2)  oncotree_code (2)  pr_status (2)  \
# 0                                0                  0              1
# 1                                0                  1              1
# 2                                1                  0              1
# 3                                0                  0              0
# 4                                1                  0              0
# ...                            ...                ...            ...
# 1511                             1                  0              1
# 1512                             1                  0              1
# 1513                             0                  0              0
# 1514                             1                  0              0
# 1515                             0                  2              1
#
#       3-gene_classifier_subtype (2)  death_from_cancer (2)  tumor_area  \
# 0                                 1                      0    0.000276
# 1                                 1                      1    0.002373
# 2                                 1                      1    0.003653
# 3                                 1                      2    0.000916
# 4                                 1                      1    0.001644
# ...                             ...                    ...         ...
# 1511                              5                      2    0.012834
# 1512                              4                      0    0.023726
# 1513                              5                      2    0.012834
# 1514                              4                      2    0.036559
# 1515                              5                      0    0.014624
#
#       Cluster
# 0           1
# 1           5
# 2           5
# 3           5
# 4           5
# ...       ...
# 1511        6
# 1512        6
# 1513        0
# 1514        6
# 1515        1
#
# [1516 rows x 34 columns]

# %%
ndf[ndf["Cluster"]==0]
# Out:
#       level_0  index  age_at_diagnosis  chemotherapy  cohort  \
# 9           9      9                68             1       1
# 29         29     29                63             1       1
# 31         31     31                69             1       1
# 48         48     48                67             0       1
# 112       112    112                63             0       1
# ...       ...    ...               ...           ...     ...
# 1464     1464   1464                68             0       4
# 1484     1484   1484                67             0       4
# 1486     1486   1486                63             0       4
# 1503     1503   1503                63             0       4
# 1513     1513   1513                61             0       4
#
#       neoplasm_histologic_grade  hormone_therapy  \
# 9                             3                0
# 29                            3                0
# 31                            3                1
# 48                            3                0
# 112                           1                1
# ...                         ...              ...
# 1464                          3                1
# 1484                          2                1
# 1486                          3                1
# 1503                          3                1
# 1513                          3                1
#
#       lymph_nodes_examined_positive  mutation_count  \
# 9                                 0               3
# 29                                4               8
# 31                                0               5
# 48                                6               1
# 112                               6               3
# ...                             ...             ...
# 1464                              0               3
# 1484                              0               5
# 1486                              1               6
# 1503                              0               4
# 1513                              1               5
#
#       nottingham_prognostic_index  ...  tumor_other_histologic_subtype (2)  \
# 9                        0.006760  ...                                   0
# 29                       0.010027  ...                                   0
# 31                       0.006760  ...                                   0
# 48                       0.000099  ...                                   0
# 112                      0.006717  ...                                   0
# ...                           ...  ...                                 ...
# 1464                     0.006704  ...                                   0
# 1484                     0.050458  ...                                   2
# 1486                     0.008359  ...                                   0
# 1503                     0.006657  ...                                   0
# 1513                     0.000082  ...                                   0
#
#       inferred_menopausal_state (2)  integrative_cluster (2)  \
# 9                                 0                        7
# 29                                0                        5
# 31                                0                        6
# 48                                0                        9
# 112                               0                        6
# ...                             ...                      ...
# 1464                              0                        6
# 1484                              0                        6
# 1486                              0                        8
# 1503                              0                       10
# 1513                              0                       10
#
#       primary_tumor_laterality (2)  oncotree_code (2)  pr_status (2)  \
# 9                                0                  0              0
# 29                               1                  0              0
# 31                               1                  0              0
# 48                               0                  0              1
# 112                              1                  0              1
# ...                            ...                ...            ...
# 1464                             1                  0              1
# 1484                             0                  2              0
# 1486                             1                  0              0
# 1503                             1                  0              0
# 1513                             0                  0              0
#
#       3-gene_classifier_subtype (2)  death_from_cancer (2)  tumor_area  \
# 9                                 0                      1    0.002312
# 29                                6                      2    0.001402
# 31                                4                      1    0.002312
# 48                                4                      1    0.004469
# 112                               4                      1    0.001523
# ...                             ...                    ...         ...
# 1464                              4                      2    0.021766
# 1484                              4                      2    0.016957
# 1486                              4                      0    0.001403
# 1503                              4                      0    0.005816
# 1513                              5                      2    0.012834
#
#       Cluster
# 9           0
# 29          0
# 31          0
# 48          0
# 112         0
# ...       ...
# 1464        0
# 1484        0
# 1486        0
# 1503        0
# 1513        0
#
# [180 rows x 34 columns]
